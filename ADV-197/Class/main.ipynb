# %%
print('Name: ')
print('Clean the data and then plot a heatmap which displays the extereme UVB value throughout the day of every month in 2015 in northern taiwan')
print('Then plot a heatmap which displays amount of Carbon monoxide release throughout the day every of month in 2015 in northern taiwan')
print('Then plot a heatmap which displays amount of sulfur dioxide release throughout the day every of month in 2015 in northern taiwan')
print('Plot both Corbon monoxide and sulfure dioxide plots beside each other to compare and find which month during which time had the most clean air in northern taiwan')
# Out:
# Name:
# Clean the data and then plot a heatmap which displays the extereme UVB value throughout the day of every month in 2015 in northern taiwan
# Then plot a heatmap which displays amount of Carbon monoxide release throughout the day every of month in 2015 in northern taiwan
# Then plot a heatmap which displays amount of sulfur dioxide release throughout the day every of month in 2015 in northern taiwan
# Plot both Corbon monoxide and sulfure dioxide plots beside each other to compare and find which month during which time had the most clean air in northern taiwan

# %% [markdown]
# # Activity 1- Plot a heatmap to show maximum UVB value throughout various different times of the day

# %%
#predefine code for image
from IPython.display import Image
Image(filename='UV.png') 
#predefine code end

# %%
# Import all the libraries and read 2015_Air_quality_in_northern_Taiwan.csv
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns 

dataframe = pd.read_csv('2015_Air_quality_in_northern_Taiwan.csv')
dataframe
# Out:
# g:\Conda\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (10,14,18) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#                     time    station AMB_TEMP  CH4    CO  NMHC   NO NO2 NOx  \
# 0       2015/01/01 00:00    Banqiao       16  2.1  0.79  0.14  1.2  16  17
# 1       2015/01/01 01:00    Banqiao       16  2.1   0.8  0.15  1.3  16  17
# 2       2015/01/01 02:00    Banqiao       16  2.1  0.71  0.13    1  13  14
# 3       2015/01/01 03:00    Banqiao       15    2  0.66  0.12  0.8  11  12
# 4       2015/01/01 04:00    Banqiao       15    2  0.53  0.11  0.6  10  11
# ...                  ...        ...      ...  ...   ...   ...  ...  ..  ..
# 218635  2015/12/31 19:00  Zhongshan       18  1.9  1.05  0.25  6.1  39  45
# 218636  2015/12/31 20:00  Zhongshan       18  1.9  0.96  0.22  5.3  37  42
# 218637  2015/12/31 21:00  Zhongshan       18  1.9  0.82  0.19    4  28  32
# 218638  2015/12/31 22:00  Zhongshan       18  1.9  0.88  0.21  4.5  32  37
# 218639  2015/12/31 23:00  Zhongshan       18  1.9  0.84  0.19  4.7  29  34
#
#         O3  ... RAINFALL RAIN_COND  RH  SO2  THC  UVB WD_HR WIND_DIREC  \
# 0       37  ...       NR        NR  57   12  2.2    0    69         69
# 1       36  ...       NR        NR  57   11  2.2    0    67         65
# 2       38  ...       NR        NR  57    8  2.2    0    63         53
# 3       39  ...       NR        NR  58  6.5  2.2    0    63         63
# 4       38  ...       NR        NR  58  5.5  2.1    0    69         67
# ...     ..  ...      ...       ...  ..  ...  ...  ...   ...        ...
# 218635  35  ...       NR       NaN  67  4.5  2.2  NaN   112        121
# 218636  31  ...       NR       NaN  69  3.7  2.1  NaN   115        113
# 218637  34  ...       NR       NaN  70  3.5  2.1  NaN   113        109
# 218638  27  ...       NR       NaN  71  4.6  2.1  NaN   116        112
# 218639  29  ...       NR       NaN  68  3.4  2.1  NaN   112        106
#
#        WIND_SPEED WS_HR
# 0             4.7   4.2
# 1               4     4
# 2             3.7   3.5
# 3             4.1   3.3
# 4               3   3.1
# ...           ...   ...
# 218635        3.2   2.3
# 218636        2.7   2.3
# 218637        2.6   2.6
# 218638        2.4   2.2
# 218639        2.9   2.3
#
# [218640 rows x 23 columns]

# %%
# Create a new column which displays the month and time extracted from the time column
dataframe['month'] = pd.DatetimeIndex(dataframe['time']).month
dataframe['time_hours'] = pd.DatetimeIndex(dataframe['time']).time

dataframe
# Out:
#                     time    station AMB_TEMP  CH4    CO  NMHC   NO NO2 NOx  \
# 0       2015/01/01 00:00    Banqiao       16  2.1  0.79  0.14  1.2  16  17
# 1       2015/01/01 01:00    Banqiao       16  2.1   0.8  0.15  1.3  16  17
# 2       2015/01/01 02:00    Banqiao       16  2.1  0.71  0.13    1  13  14
# 3       2015/01/01 03:00    Banqiao       15    2  0.66  0.12  0.8  11  12
# 4       2015/01/01 04:00    Banqiao       15    2  0.53  0.11  0.6  10  11
# ...                  ...        ...      ...  ...   ...   ...  ...  ..  ..
# 218635  2015/12/31 19:00  Zhongshan       18  1.9  1.05  0.25  6.1  39  45
# 218636  2015/12/31 20:00  Zhongshan       18  1.9  0.96  0.22  5.3  37  42
# 218637  2015/12/31 21:00  Zhongshan       18  1.9  0.82  0.19    4  28  32
# 218638  2015/12/31 22:00  Zhongshan       18  1.9  0.88  0.21  4.5  32  37
# 218639  2015/12/31 23:00  Zhongshan       18  1.9  0.84  0.19  4.7  29  34
#
#         O3  ...  RH  SO2  THC  UVB WD_HR WIND_DIREC WIND_SPEED WS_HR month  \
# 0       37  ...  57   12  2.2    0    69         69        4.7   4.2     1
# 1       36  ...  57   11  2.2    0    67         65          4     4     1
# 2       38  ...  57    8  2.2    0    63         53        3.7   3.5     1
# 3       39  ...  58  6.5  2.2    0    63         63        4.1   3.3     1
# 4       38  ...  58  5.5  2.1    0    69         67          3   3.1     1
# ...     ..  ...  ..  ...  ...  ...   ...        ...        ...   ...   ...
# 218635  35  ...  67  4.5  2.2  NaN   112        121        3.2   2.3    12
# 218636  31  ...  69  3.7  2.1  NaN   115        113        2.7   2.3    12
# 218637  34  ...  70  3.5  2.1  NaN   113        109        2.6   2.6    12
# 218638  27  ...  71  4.6  2.1  NaN   116        112        2.4   2.2    12
# 218639  29  ...  68  3.4  2.1  NaN   112        106        2.9   2.3    12
#
#        time_hours
# 0        00:00:00
# 1        01:00:00
# 2        02:00:00
# 3        03:00:00
# 4        04:00:00
# ...           ...
# 218635   19:00:00
# 218636   20:00:00
# 218637   21:00:00
# 218638   22:00:00
# 218639   23:00:00
#
# [218640 rows x 25 columns]

# %%
# Clean the data by replacing the null, 0 and values ending with # to nan values
dataframe.replace( '', float('nan') ,inplace=True)
dataframe.replace( '0', float('nan') ,inplace=True)
dataframe.replace('.#$', float('nan') ,inplace=True, regex=True)
dataframe.replace('.x$', float('nan') ,inplace=True, regex=True)
df = dataframe.dropna()
df
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10344/2830140075.py in <module>
#       2 dataframe.replace( '', float('nan') ,inplace=True)
#       3 dataframe.replace( '0', float('nan') ,inplace=True)
# ----> 4 dataframe.replace('.#$', float('nan') ,inplace=True, regex=True)
#       5 dataframe.replace('.x$', float('nan') ,inplace=True, regex=True)
#       6 df = dataframe.dropna()
#
# g:\Conda\lib\site-packages\pandas\core\frame.py in replace(self, to_replace, value, inplace, limit, regex, method)
#    5236         method: str = "pad",
#    5237     ):
# -> 5238         return super().replace(
#    5239             to_replace=to_replace,
#    5240             value=value,
#
# g:\Conda\lib\site-packages\pandas\core\generic.py in replace(self, to_replace, value, inplace, limit, regex, method)
#    6607
#    6608                 elif not is_list_like(value):  # NA -> 0
# -> 6609                     new_data = self._mgr.replace(
#    6610                         to_replace=to_replace, value=value, inplace=inplace, regex=regex
#    6611                     )
#
# g:\Conda\lib\site-packages\pandas\core\internals\managers.py in replace(self, to_replace, value, inplace, regex)
#     435     def replace(self: T, to_replace, value, inplace: bool, regex: bool) -> T:
#     436         assert np.ndim(value) == 0, value
# --> 437         return self.apply(
#     438             "replace", to_replace=to_replace, value=value, inplace=inplace, regex=regex
#     439         )
#
# g:\Conda\lib\site-packages\pandas\core\internals\managers.py in apply(self, f, align_keys, ignore_failures, **kwargs)
#     325                     applied = b.apply(f, **kwargs)
#     326                 else:
# --> 327                     applied = getattr(b, f)(**kwargs)
#     328             except (TypeError, NotImplementedError):
#     329                 if not ignore_failures:
#
# g:\Conda\lib\site-packages\pandas\core\internals\blocks.py in replace(self, to_replace, value, inplace, regex)
#     684
#     685         if regex:
# --> 686             return self._replace_regex(to_replace, value, inplace=inplace)
#     687
#     688         if not self._can_hold_element(to_replace):
#
# g:\Conda\lib\site-packages\pandas\core\internals\blocks.py in _replace_regex(self, to_replace, value, inplace, convert, mask)
#     757
#     758         new_values = self.values if inplace else self.values.copy()
# --> 759         replace_regex(new_values, rx, value, mask)
#     760
#     761         block = self.make_block(new_values)
#
# g:\Conda\lib\site-packages\pandas\core\array_algos\replace.py in replace_regex(values, rx, value, mask)
#     153
#     154     if mask is None:
# --> 155         values[:] = f(values)
#     156     else:
#     157         values[mask] = f(values[mask])
#
# g:\Conda\lib\site-packages\numpy\lib\function_base.py in __call__(self, *args, **kwargs)
#    2111             vargs.extend([kwargs[_n] for _n in names])
#    2112
# -> 2113         return self._vectorize_call(func=func, args=vargs)
#    2114
#    2115     def _get_ufunc_and_otypes(self, func, args):
#
# g:\Conda\lib\site-packages\numpy\lib\function_base.py in _vectorize_call(self, func, args)
#    2195                       for a in args]
#    2196
# -> 2197             outputs = ufunc(*inputs)
#    2198
#    2199             if ufunc.nout == 1:
#
# g:\Conda\lib\site-packages\pandas\core\array_algos\replace.py in re_replacer(s)
#     136
#     137         def re_replacer(s):
# --> 138             if is_re(rx) and isinstance(s, str):
#     139                 return value if rx.search(s) is not None else s
#     140             else:
#
# KeyboardInterrupt:

# %%
# Set the type of 'UVB' column to float
df['UVB'] = df['UVB'].astype(float)
df['UVB'].dtypes
# Out:
# C:\Users\prana\AppData\Local\Temp/ipykernel_10344/1490045963.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['UVB'] = df['UVB'].astype(float)
# dtype('float64')

# %%
#groupby the month and time for getting the maximum of UVB value
new_dataframe = df.groupby(['month','time_hours'])['UVB'].max().reset_index()
new_dataframe
# Out:
#      month time_hours  UVB
# 0        1   07:00:00  0.3
# 1        1   08:00:00  1.3
# 2        1   09:00:00  3.0
# 3        1   10:00:00  4.4
# 4        1   11:00:00  5.8
# ..     ...        ...  ...
# 138     12   12:00:00  5.0
# 139     12   13:00:00  3.9
# 140     12   14:00:00  2.3
# 141     12   15:00:00  0.9
# 142     12   16:00:00  0.2
#
# [143 rows x 3 columns]

# %%
# Plot a heatmap to show the UV value for through various times of the day 

plt.figure(figsize=(10,8))
heatmap_df = pd.pivot_table(values ='UVB', index ='time_hours',  
                    columns ='month', data = new_dataframe)
sns.heatmap(heatmap_df, cmap ='plasma')
# Out:
# <AxesSubplot:xlabel='month', ylabel='time_hours'>

# %% [markdown]
# Conclusion - In the month of 5th to 8th (i.e from May to August) at the time between 11 am to 1 pm, the UVB rays can affect people the most and may lead to sun burn and skin cancer.

# %% [markdown]
# # Activity 2 Plot a heatmap to show when the air was most clean as per release of Carbon monoxide and Sulfur dioxide at various different times of the day

# %% [markdown]
# Carbon monoxide - is a colorless, odorless, and tasteless flammable gas that is slightly less dense than air. It is an toxic air.
#
# Sulfur dioxide - It is a toxic gas responsible for the smell of burnt matches.

# %%
#predefine code for image
from IPython.display import Image
Image(filename='air.jpg') 
#predefine code end

# %%
# Set the type of 'SO2' column to float 
df["SO2"].astype("float")
df
# Out:
#                   time  station AMB_TEMP  CH4    CO  NMHC   NO NO2 NOx  O3  \
# 160   2015/01/07 16:00  Banqiao       15    2  0.83  0.27  7.8  30  38  13
# 175   2015/01/08 07:00  Banqiao       12    2  0.69  0.19  5.3  22  27  20
# 176   2015/01/08 08:00  Banqiao       13  1.9  0.71   0.2  7.7  23  31  20
# 177   2015/01/08 09:00  Banqiao       13  1.9  0.61  0.18  6.1  21  27  23
# 178   2015/01/08 10:00  Banqiao       14  1.9  0.65  0.23  8.3  24  33  22
# ...                ...      ...      ...  ...   ...   ...  ...  ..  ..  ..
# 8748  2015/12/31 12:00  Banqiao       17    2  0.64   0.2  3.7  24  28  36
# 8749  2015/12/31 13:00  Banqiao       17    2  0.66   0.2  3.7  24  27  36
# 8750  2015/12/31 14:00  Banqiao       17    2  0.71  0.22  4.4  28  32  31
# 8751  2015/12/31 15:00  Banqiao       17    2  0.79  0.25  4.7  31  35  28
# 8752  2015/12/31 16:00  Banqiao       17    2  0.84  0.36  6.5  38  45  21
#
#       ...  RH  SO2  THC  UVB WD_HR WIND_DIREC WIND_SPEED WS_HR  month  \
# 160   ...  69  2.1  2.3  0.1    78         71          2   1.9      1
# 175   ...  55  4.8  2.1  0.2    63         56          3   2.4      1
# 176   ...  53  5.1  2.1  0.7    65         60        3.2   2.5      1
# 177   ...  54  5.2  2.1  1.2    55         53        2.7   2.6      1
# 178   ...  52  5.3  2.2  1.7    79         93        2.5   2.3      1
# ...   ...  ..  ...  ...  ...   ...        ...        ...   ...    ...
# 8748  ...  59  4.1  2.2  0.8    73         73        3.5   2.7     12
# 8749  ...  59  4.6  2.2  0.8    80         76        2.4   2.4     12
# 8750  ...  60    5  2.2  0.4    77         77        2.4   2.5     12
# 8751  ...  60  5.1  2.2  0.2    82         88        1.7   2.2     12
# 8752  ...  61  5.3  2.4  0.1    84         83        1.4   1.4     12
#
#      time_hours
# 160    16:00:00
# 175    07:00:00
# 176    08:00:00
# 177    09:00:00
# 178    10:00:00
# ...         ...
# 8748   12:00:00
# 8749   13:00:00
# 8750   14:00:00
# 8751   15:00:00
# 8752   16:00:00
#
# [3673 rows x 25 columns]

# %%
# Set the type of 'CO' column to float 
df["CO"].astype("float")
df
# Out:
#                   time  station AMB_TEMP  CH4    CO  NMHC   NO NO2 NOx  O3  \
# 160   2015/01/07 16:00  Banqiao       15    2  0.83  0.27  7.8  30  38  13
# 175   2015/01/08 07:00  Banqiao       12    2  0.69  0.19  5.3  22  27  20
# 176   2015/01/08 08:00  Banqiao       13  1.9  0.71   0.2  7.7  23  31  20
# 177   2015/01/08 09:00  Banqiao       13  1.9  0.61  0.18  6.1  21  27  23
# 178   2015/01/08 10:00  Banqiao       14  1.9  0.65  0.23  8.3  24  33  22
# ...                ...      ...      ...  ...   ...   ...  ...  ..  ..  ..
# 8748  2015/12/31 12:00  Banqiao       17    2  0.64   0.2  3.7  24  28  36
# 8749  2015/12/31 13:00  Banqiao       17    2  0.66   0.2  3.7  24  27  36
# 8750  2015/12/31 14:00  Banqiao       17    2  0.71  0.22  4.4  28  32  31
# 8751  2015/12/31 15:00  Banqiao       17    2  0.79  0.25  4.7  31  35  28
# 8752  2015/12/31 16:00  Banqiao       17    2  0.84  0.36  6.5  38  45  21
#
#       ...  RH  SO2  THC  UVB WD_HR WIND_DIREC WIND_SPEED WS_HR  month  \
# 160   ...  69  2.1  2.3  0.1    78         71          2   1.9      1
# 175   ...  55  4.8  2.1  0.2    63         56          3   2.4      1
# 176   ...  53  5.1  2.1  0.7    65         60        3.2   2.5      1
# 177   ...  54  5.2  2.1  1.2    55         53        2.7   2.6      1
# 178   ...  52  5.3  2.2  1.7    79         93        2.5   2.3      1
# ...   ...  ..  ...  ...  ...   ...        ...        ...   ...    ...
# 8748  ...  59  4.1  2.2  0.8    73         73        3.5   2.7     12
# 8749  ...  59  4.6  2.2  0.8    80         76        2.4   2.4     12
# 8750  ...  60    5  2.2  0.4    77         77        2.4   2.5     12
# 8751  ...  60  5.1  2.2  0.2    82         88        1.7   2.2     12
# 8752  ...  61  5.3  2.4  0.1    84         83        1.4   1.4     12
#
#      time_hours
# 160    16:00:00
# 175    07:00:00
# 176    08:00:00
# 177    09:00:00
# 178    10:00:00
# ...         ...
# 8748   12:00:00
# 8749   13:00:00
# 8750   14:00:00
# 8751   15:00:00
# 8752   16:00:00
#
# [3673 rows x 25 columns]

# %%
#Groupby the month and time for getting the maximum of CO and SO2
act2 = df.groupby(['month', 'time_hours'])["CO"].max().reset_index()
act2
# Out:
#      month time_hours    CO
# 0        1   07:00:00  1.19
# 1        1   08:00:00   1.9
# 2        1   09:00:00  1.54
# 3        1   10:00:00  0.83
# 4        1   11:00:00  0.76
# ..     ...        ...   ...
# 138     12   12:00:00  0.92
# 139     12   13:00:00  0.81
# 140     12   14:00:00  0.78
# 141     12   15:00:00  0.94
# 142     12   16:00:00  0.87
#
# [143 rows x 3 columns]

# %%
# Plot a heatmap to show the the amount of carbon monoxide release through various different times of the day 
plt.figure(figsize=(10,8))
heatmap1 = pd.pivot_table(values ='CO', index ='time_hours',  
                    columns ='month', data = act2)
sns.heatmap(heatmap1, cmap ='plasma')
# Out:
# <AxesSubplot:xlabel='month', ylabel='time_hours'>

# %% [markdown]
# Conclusion - In the month of 3th to 7th (i.e from March to July) between 12 pm to 2 pm the air contained least amount of Carbon monoxide

# %%
# Plot a heatmap to show the amount Sulfur dioxide released through various different times of the day 
act3 = df.groupby(['month', 'time_hours'])["SO2"].max().reset_index()
act3
# Out:
#      month time_hours  SO2
# 0        1   07:00:00  8.9
# 1        1   08:00:00    9
# 2        1   09:00:00  8.3
# 3        1   10:00:00  7.5
# 4        1   11:00:00  6.5
# ..     ...        ...  ...
# 138     12   12:00:00  9.7
# 139     12   13:00:00  9.2
# 140     12   14:00:00  6.1
# 141     12   15:00:00  5.8
# 142     12   16:00:00  7.8
#
# [143 rows x 3 columns]

# %%
plt.figure(figsize=(10,8))
heatmap2 = pd.pivot_table(values ='SO2', index ='time_hours',  
                    columns ='month', data = act3)
sns.heatmap(heatmap2, cmap ='plasma')
# Out:
# <AxesSubplot:xlabel='month', ylabel='time_hours'>

# %%
# plot both the amount of carbon monoxide and sulfur dioxide released during different hours of the day
# and find the time and month during which both the gases where at its minimum which is clean air

fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(15,7))

sns.heatmap(heatmap1, cmap="plasma", ax=ax1)
ax1.title.set_text("CO")
sns.heatmap(heatmap2, cmap="plasma", ax=ax2)
ax2.title.set_text("SO2")

# %% [markdown]
# Conclusion -
